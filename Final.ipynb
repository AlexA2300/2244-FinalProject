# %% [markdown]
# ---
# ## Initialization
# ---

# %%
import gymnasium as gym

import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder

# %% [markdown]
# ---
# ## PPO Implementation
# ---

# %%
#creates the environment
env = make_vec_env("LunarLander-v2", n_envs = 16)

#implements PPO
model = PPO(policy = "MlpPolicy", env = env, n_steps =1024, batch_size = 64, n_epochs = 4, gamma = 0.999,
            gae_lambda = 0.98, ent_coef = 0.01, verbose = 1)
# Out:
# Using cuda device

# %%
# trains the model 1000000 timesteps
model.learn(total_timesteps = 1000000)

model.save('LunarLanderPPO')
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.5     |
# |    ep_rew_mean     | -174     |
# | time/              |          |
# |    fps             | 3921     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.8         |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 2323         |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0076965694 |
# |    clip_fraction        | 0.0633       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -1.79e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00602     |
# |    value_loss           | 4.5e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -134        |
# | time/                   |             |
# |    fps                  | 2005        |
# |    iterations           | 3           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008571682 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00516    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00615    |
# |    value_loss           | 1.92e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 4            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0060050157 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00214     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 654          |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 1.38e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 1830        |
# |    iterations           | 5           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006016565 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.000204    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 492         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 904         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -90.3       |
# | time/                   |             |
# |    fps                  | 1747        |
# |    iterations           | 6           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010537065 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00703    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 404         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00458    |
# |    value_loss           | 693         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -64.9       |
# | time/                   |             |
# |    fps                  | 1720        |
# |    iterations           | 7           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008578047 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.00179    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 232         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00593    |
# |    value_loss           | 533         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | -58         |
# | time/                   |             |
# |    fps                  | 1671        |
# |    iterations           | 8           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.010153735 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -0.000846   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 146         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 457         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | -29.6        |
# | time/                   |              |
# |    fps                  | 1616         |
# |    iterations           | 9            |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0063215075 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.0129       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 245          |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 596          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | -27.8       |
# | time/                   |             |
# |    fps                  | 1550        |
# |    iterations           | 10          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.009500698 |
# |    clip_fraction        | 0.0553      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.0579     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 280         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 551         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | -12.1        |
# | time/                   |              |
# |    fps                  | 1484         |
# |    iterations           | 11           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0064140735 |
# |    clip_fraction        | 0.0675       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.00153     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 377          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 582          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | -18.3        |
# | time/                   |              |
# |    fps                  | 1405         |
# |    iterations           | 12           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0067756507 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -8.81e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 327          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 524          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -10.6        |
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 13           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0039903615 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 1.6e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 354          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.000562    |
# |    value_loss           | 603          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 214          |
# |    ep_rew_mean          | -3.5         |
# | time/                   |              |
# |    fps                  | 1274         |
# |    iterations           | 14           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0045896056 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.000108     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 191          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00349     |
# |    value_loss           | 412          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 247          |
# |    ep_rew_mean          | 4.69         |
# | time/                   |              |
# |    fps                  | 1219         |
# |    iterations           | 15           |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0032949145 |
# |    clip_fraction        | 0.00134      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 293          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 474          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 313         |
# |    ep_rew_mean          | 7.22        |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 16          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.005684816 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 383         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 423          |
# |    ep_rew_mean          | 13.4         |
# | time/                   |              |
# |    fps                  | 1100         |
# |    iterations           | 17           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0053762514 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 250          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 484          |
# |    ep_rew_mean          | 17.5         |
# | time/                   |              |
# |    fps                  | 1055         |
# |    iterations           | 18           |
# |    time_elapsed         | 279          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0074365786 |
# |    clip_fraction        | 0.0793       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 84.1         |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 213          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 558        |
# |    ep_rew_mean          | 26.9       |
# | time/                   |            |
# |    fps                  | 1023       |
# |    iterations           | 19         |
# |    time_elapsed         | 304        |
# |    total_timesteps      | 311296     |
# | train/                  |            |
# |    approx_kl            | 0.00410663 |
# |    clip_fraction        | 0.0275     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.738      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 77.7       |
# |    n_updates            | 72         |
# |    policy_gradient_loss | -0.00188   |
# |    value_loss           | 182        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 609         |
# |    ep_rew_mean          | 35.3        |
# | time/                   |             |
# |    fps                  | 987         |
# |    iterations           | 20          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.006638093 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.4        |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 240         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 614         |
# |    ep_rew_mean          | 44.1        |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 21          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.006793091 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.4        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00105    |
# |    value_loss           | 99.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 626          |
# |    ep_rew_mean          | 48.8         |
# | time/                   |              |
# |    fps                  | 945          |
# |    iterations           | 22           |
# |    time_elapsed         | 381          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0066092364 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 82.6         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 130          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 665          |
# |    ep_rew_mean          | 58.1         |
# | time/                   |              |
# |    fps                  | 924          |
# |    iterations           | 23           |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0048987977 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 146          |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 103          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | 66.4        |
# | time/                   |             |
# |    fps                  | 906         |
# |    iterations           | 24          |
# |    time_elapsed         | 433         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.005997973 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.2        |
# |    n_updates            | 92          |
# |    policy_gradient_loss | -0.00171    |
# |    value_loss           | 81.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 748          |
# |    ep_rew_mean          | 80.6         |
# | time/                   |              |
# |    fps                  | 891          |
# |    iterations           | 25           |
# |    time_elapsed         | 459          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0037564556 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.7         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 88.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 715          |
# |    ep_rew_mean          | 83.7         |
# | time/                   |              |
# |    fps                  | 880          |
# |    iterations           | 26           |
# |    time_elapsed         | 483          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0048245387 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18           |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 64.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 699          |
# |    ep_rew_mean          | 86           |
# | time/                   |              |
# |    fps                  | 869          |
# |    iterations           | 27           |
# |    time_elapsed         | 508          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0043928074 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.6         |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 115          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 700          |
# |    ep_rew_mean          | 87.8         |
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 28           |
# |    time_elapsed         | 532          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0038169513 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 74.8         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 107          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 696        |
# |    ep_rew_mean          | 88.4       |
# | time/                   |            |
# |    fps                  | 854        |
# |    iterations           | 29         |
# |    time_elapsed         | 556        |
# |    total_timesteps      | 475136     |
# | train/                  |            |
# |    approx_kl            | 0.00523481 |
# |    clip_fraction        | 0.0207     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25         |
# |    n_updates            | 112        |
# |    policy_gradient_loss | -0.00054   |
# |    value_loss           | 63.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 713         |
# |    ep_rew_mean          | 92.5        |
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 30          |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.004956558 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.7        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 749         |
# |    ep_rew_mean          | 97.2        |
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 31          |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.007040179 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00122    |
# |    value_loss           | 84.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 774          |
# |    ep_rew_mean          | 99.4         |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 32           |
# |    time_elapsed         | 627          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0035098009 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.9         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.0005      |
# |    value_loss           | 90.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 746         |
# |    ep_rew_mean          | 94.9        |
# | time/                   |             |
# |    fps                  | 831         |
# |    iterations           | 33          |
# |    time_elapsed         | 650         |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.008063126 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 73.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 776          |
# |    ep_rew_mean          | 99.7         |
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 34           |
# |    time_elapsed         | 674          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0032251445 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72           |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000467    |
# |    value_loss           | 129          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 760         |
# |    ep_rew_mean          | 96.5        |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 35          |
# |    time_elapsed         | 698         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.005433862 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.8         |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.000541   |
# |    value_loss           | 44.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 782          |
# |    ep_rew_mean          | 103          |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 36           |
# |    time_elapsed         | 721          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0048844335 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.8         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000687    |
# |    value_loss           | 68.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 822          |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 37           |
# |    time_elapsed         | 742          |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0061401986 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.9         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 53.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 851         |
# |    ep_rew_mean          | 119         |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 38          |
# |    time_elapsed         | 766         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.005468893 |
# |    clip_fraction        | 0.0567      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.54        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 12.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 874          |
# |    ep_rew_mean          | 124          |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 39           |
# |    time_elapsed         | 789          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0048377877 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.2         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 53           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 882          |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 40           |
# |    time_elapsed         | 813          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0034160453 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.6         |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 35.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 875          |
# |    ep_rew_mean          | 122          |
# | time/                   |              |
# |    fps                  | 802          |
# |    iterations           | 41           |
# |    time_elapsed         | 836          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0032565347 |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000464    |
# |    value_loss           | 35.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 867         |
# |    ep_rew_mean          | 120         |
# | time/                   |             |
# |    fps                  | 799         |
# |    iterations           | 42          |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.005889306 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.000592   |
# |    value_loss           | 68.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 875          |
# |    ep_rew_mean          | 120          |
# | time/                   |              |
# |    fps                  | 796          |
# |    iterations           | 43           |
# |    time_elapsed         | 884          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0033350154 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.5         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.000634    |
# |    value_loss           | 41.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 883          |
# |    ep_rew_mean          | 123          |
# | time/                   |              |
# |    fps                  | 793          |
# |    iterations           | 44           |
# |    time_elapsed         | 908          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0063306903 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.46         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.000913    |
# |    value_loss           | 36.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 891          |
# |    ep_rew_mean          | 124          |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 45           |
# |    time_elapsed         | 933          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0054175667 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.981       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.96         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 14.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 46           |
# |    time_elapsed         | 958          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0040182243 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.996       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.3         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000164    |
# |    value_loss           | 27.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 946         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 47          |
# |    time_elapsed         | 983         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.006915888 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.992      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.85        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.000816   |
# |    value_loss           | 22.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 48          |
# |    time_elapsed         | 1009        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.006788145 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.03        |
# |    n_updates            | 188         |
# |    policy_gradient_loss | -0.00175    |
# |    value_loss           | 5.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 970         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 49          |
# |    time_elapsed         | 1034        |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.004594045 |
# |    clip_fraction        | 0.0275      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.000746   |
# |    value_loss           | 19.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 971         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 50          |
# |    time_elapsed         | 1059        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.004544897 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5         |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.000689   |
# |    value_loss           | 7.4         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 978        |
# |    ep_rew_mean          | 146        |
# | time/                   |            |
# |    fps                  | 770        |
# |    iterations           | 51         |
# |    time_elapsed         | 1084       |
# |    total_timesteps      | 835584     |
# | train/                  |            |
# |    approx_kl            | 0.00783084 |
# |    clip_fraction        | 0.0431     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.945     |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.44       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00174   |
# |    value_loss           | 15.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 986         |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 52          |
# |    time_elapsed         | 1109        |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.004526822 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | -0.000494   |
# |    value_loss           | 4.47        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 986         |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 765         |
# |    iterations           | 53          |
# |    time_elapsed         | 1133        |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.004158444 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.938      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.45        |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -0.000214   |
# |    value_loss           | 4.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 978         |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 54          |
# |    time_elapsed         | 1158        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.005972706 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.901       |
# |    n_updates            | 212         |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 3.73        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 962          |
# |    ep_rew_mean          | 148          |
# | time/                   |              |
# |    fps                  | 762          |
# |    iterations           | 55           |
# |    time_elapsed         | 1181         |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0041150926 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.879       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.955        |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.000824    |
# |    value_loss           | 26.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 962          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 761          |
# |    iterations           | 56           |
# |    time_elapsed         | 1204         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0028074165 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.855       |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.4         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000299     |
# |    value_loss           | 48.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 924         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 57          |
# |    time_elapsed         | 1226        |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.004917959 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.7        |
# |    n_updates            | 224         |
# |    policy_gradient_loss | -0.000763   |
# |    value_loss           | 45.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 903          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 761          |
# |    iterations           | 58           |
# |    time_elapsed         | 1248         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0050873645 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.777       |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.2         |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 121          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 853        |
# |    ep_rew_mean          | 175        |
# | time/                   |            |
# |    fps                  | 761        |
# |    iterations           | 59         |
# |    time_elapsed         | 1269       |
# |    total_timesteps      | 966656     |
# | train/                  |            |
# |    approx_kl            | 0.00506361 |
# |    clip_fraction        | 0.0724     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.735     |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.19       |
# |    n_updates            | 232        |
# |    policy_gradient_loss | -0.00285   |
# |    value_loss           | 124        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 743          |
# |    ep_rew_mean          | 189          |
# | time/                   |              |
# |    fps                  | 762          |
# |    iterations           | 60           |
# |    time_elapsed         | 1289         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0038489369 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.7         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 188          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 593          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 764          |
# |    iterations           | 61           |
# |    time_elapsed         | 1307         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0050471406 |
# |    clip_fraction        | 0.0705       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.7         |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97.1         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 338          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 766         |
# |    iterations           | 62          |
# |    time_elapsed         | 1324        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.005658534 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 250         |
# |    n_updates            | 244         |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 361         |
# -----------------------------------------

# %% [markdown]
# ---
# Evaluation
# ---

# %%
evalEnv = Monitor(gym.make("LunarLander-v2"))

meanReward, stdReward = evaluate_policy(model, evalEnv, n_eval_episodes = 10, deterministic=True)

print(f"mean reward= {meanReward:.2f} +/- {stdReward}")
# Out:
# mean reward= 250.32 +/- 18.524214364704232

# %% [markdown]
# ---
# Recording
# ---

# %%
#loading in trained model
model = PPO.load('LunarLanderPPO')

#set up for video
env = DummyVecEnv([lambda: gym.make("LunarLander-v2", render_mode="rgb_array")])

env = VecVideoRecorder(env, 'videos/', record_video_trigger=lambda x: x == 0, video_length = 1000, name_prefix="lunarlanderPPO")

# reseting the environment and start recording
obs = env.reset()

for i in range(1000):

    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = env.step(action)

env.close()
# Out:
# Saving video to /content/videos/lunarlanderPPO-step-0-to-step-1000.mp4
# Moviepy - Building video /content/videos/lunarlanderPPO-step-0-to-step-1000.mp4.
# Moviepy - Writing video /content/videos/lunarlanderPPO-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/videos/lunarlanderPPO-step-0-to-step-1000.mp4
